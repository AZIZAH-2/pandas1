# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df['Pregnancies']
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64

# %%
plt.plot(df['Pregnancies'])

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.xlabel('Horiziontal')
plt.ylabel('vertical')
plt.title('Data Analysis')
plt.show()

# %%
x = df.Age
y = df.Outcome
z = df.BloodPressure
plt.plot(x,y,z)
# Out:
# [<matplotlib.lines.Line2D at 0xb84bc70>,
#  <matplotlib.lines.Line2D at 0xb84ba48>]

# %%
data = df['Age'].value_counts()
data.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df['Age'].value_counts().index
# Out:
# Int64Index([22, 21, 25, 24, 23, 28, 26, 27, 29, 31, 41, 30, 37, 42, 33, 38, 36,
#             32, 45, 34, 46, 43, 40, 39, 35, 50, 51, 52, 44, 58, 47, 54, 49, 48,
#             57, 53, 60, 66, 63, 62, 55, 67, 56, 59, 65, 69, 61, 72, 81, 64, 70,
#             68],
#            dtype='int64')

# %%
data = df['Age'].value_counts()
data.plot(kind='pie', autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Age'>
