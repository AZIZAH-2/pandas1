# %%
import pandas as pd

# %%
dataset = pd.read_csv("bank-deposits-distributed-by-type_march22_m.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                Table  (11)  جــدول         NaN
# 2         NaN                                                NaN         NaN
# 3         NaN  الـودائـــــع الـمـصـرفـيــة مـوزعــة حــســــ...         NaN
# 4         NaN                 BANK DEPOSITS DISTRIBUTED BY TYPE          NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %%
dataset.tail()
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 365         NaN                                                NaN
# 366         NaN  *  Which comprise residents' foreign currency ...
# 367         NaN      outstanding remittances, and banks Repo tr...
# 368         NaN  Note: The data are updated. The data of foreig...
# 369         NaN  amended and updated as per international best ...
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 365         NaN        NaN        NaN        NaN        NaN        NaN
# 366         NaN        NaN        NaN        NaN        NaN        NaN
# 367         NaN        NaN        NaN        NaN        NaN        NaN
# 368         NaN        NaN        NaN        NaN        NaN        NaN
# 369         NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# ...
